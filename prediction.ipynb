# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Load saved model
model = load_model("/content/deepfake_detector.keras")

# Path of image to test
img_path = "/content/image.jpeg"

# Load and display image
img = image.load_img(img_path, target_size=(224, 224))

plt.imshow(img)
plt.axis("off")
plt.show()

# Convert image to array
img_array = image.img_to_array(img)

# Normalize image
img_array = img_array / 255.0

# Add batch dimension
img_array = np.expand_dims(img_array, axis=0)

# Predict
prediction = model.predict(img_array)

# Print raw prediction value
print("Prediction Score:", prediction[0][0])

# Final result
if prediction[0][0] > 0.5:
    print("Real Image")
else:
    print("Fake Image")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1207/2995197796.py in <cell line: 0>()
#       5
#       6 # Load saved model
# ----> 7 model = load_model("/content/deepfake_detector.keras")
#       8
#       9 # Path of image to test
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     201         )
#     202     elif str(filepath).endswith(".keras"):
# --> 203         raise ValueError(
#     204             f"File not found: filepath={filepath}. "
#     205             "Please ensure the file is an accessible `.keras` "
#
# ValueError: File not found: filepath=/content/deepfake_detector.keras. Please ensure the file is an accessible `.keras` zip file.
